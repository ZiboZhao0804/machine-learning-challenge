# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
#target value counts
df['koi_disposition'].value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %%
# Set features. This will also be used as your x values.
selected_features = df[['koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
       'koi_fpflag_ec', 'koi_period', 'koi_time0bk', 'koi_impact','koi_duration', 'koi_depth', 'koi_prad', 
       'koi_teq', 'koi_insol', 'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff',  'koi_slogg', 
       'koi_srad',  'ra', 'dec','koi_kepmag']]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
target = df['koi_disposition']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(selected_features,target,test_size = 0.2)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 711               0              1              0              0    2.380863
# 4881              0              0              0              0  279.219570
# 4765              0              1              0              1    0.779616
# 273               0              1              1              1    8.667822
# 5972              0              0              0              0   14.157372
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 711    135.325212      0.6640       4.20416    32634.0     21.65     1480
# 4881   179.927400      0.6009      10.01500      333.5      4.92      395
# 4765   131.680060      0.6990       3.93200       81.5      0.83     1847
# 273    137.341841      1.2760       4.96580     2121.9     67.37     1303
# 5972   135.599100      0.1380       3.78600      130.0      1.10      778
#
#       koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  koi_slogg  \
# 711     1133.00         2590.6                 1       5821      4.297
# 4881       5.77           10.5                 1       5159      3.648
# 4765    2735.51           22.0                 1       5764      4.548
# 273      681.39          187.6                 1       6266      3.923
# 5972      86.67            9.3                 3       6122      4.487
#
#       koi_srad         ra        dec  koi_kepmag
# 711      1.129  289.79077  48.448139      13.802
# 4881     2.604  288.40182  45.677029      13.845
# 4765     0.863  296.73291  43.864319      15.292
# 273      1.889  299.39972  45.316051      13.030
# 5972     0.964  292.31601  42.626251      14.718

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
# no need for SVC
#from sklearn.preprocessing import MinMaxScaler
#X_scaler = MinMaxScaler().fit(selected_features)
#X_train_scaled = X_scaler.transform(X_train)
#X_test_scaled = X_scaler.transform(X_test)
X_train_scaled = X_train
X_test_scaled = X_test

# %% [markdown]
# # Train the Model
# ## Decision Tree

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear')
svc.fit(X_train_scaled,y_train)
# Out:
# SVC(kernel='linear')

# %%
print(f"Training Data Score: {svc.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {svc.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7639484978540773
# Testing Data Score: 0.7605432451751251

# %%
predictions = svc.predict(X_test_scaled)
pd.DataFrame({"actual":y_test,"prediction":predictions},columns = ["actual","prediction"]).head(20)
# Out:
#               actual      prediction
# 2762       CONFIRMED       CONFIRMED
# 4524  FALSE POSITIVE  FALSE POSITIVE
# 3294       CANDIDATE       CONFIRMED
# 3031       CANDIDATE       CANDIDATE
# 3932       CONFIRMED       CANDIDATE
# 5247       CANDIDATE       CANDIDATE
# 1362       CONFIRMED       CONFIRMED
# 2841  FALSE POSITIVE  FALSE POSITIVE
# 691   FALSE POSITIVE  FALSE POSITIVE
# 1586       CONFIRMED       CONFIRMED
# 1011       CONFIRMED       CONFIRMED
# 489        CONFIRMED       CONFIRMED
# 247        CONFIRMED       CONFIRMED
# 2411       CANDIDATE       CONFIRMED
# 4156  FALSE POSITIVE  FALSE POSITIVE
# 486   FALSE POSITIVE  FALSE POSITIVE
# 4769  FALSE POSITIVE       CONFIRMED
# 5706       CANDIDATE       CONFIRMED
# 202        CONFIRMED       CONFIRMED
# 5318       CANDIDATE       CANDIDATE

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {"C":[1,5]}
grid = GridSearchCV(svc,param_grid,verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled,y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits

# %%
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
